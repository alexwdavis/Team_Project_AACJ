# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("police.csv")

# %%
df.head()
# Out:
#    IncidntNum         Category                                   Descript  \
# 0   150060275     NON-CRIMINAL                              LOST PROPERTY
# 1   150098210          ROBBERY                      ROBBERY, BODILY FORCE
# 2   150098210          ASSAULT       AGGRAVATED ASSAULT WITH BODILY FORCE
# 3   150098210  SECONDARY CODES                          DOMESTIC VIOLENCE
# 4   150098226        VANDALISM  MALICIOUS MISCHIEF, VANDALISM OF VEHICLES
#
#   DayOfWeek        Date   Time  PdDistrict Resolution  \
# 0    Monday  01/19/2015  14:00     MISSION       NONE
# 1    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 2    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 3    Sunday  02/01/2015  15:45  TENDERLOIN       NONE
# 4   Tuesday  01/27/2015  19:00    NORTHERN       NONE
#
#                        Address           X          Y  \
# 0        18TH ST / VALENCIA ST -122.421582  37.761701
# 1  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 2  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 3  300 Block of LEAVENWORTH ST -122.414406  37.784191
# 4       LOMBARD ST / LAGUNA ST -122.431119  37.800469
#
#                                 Location            PdId
# 0   (37.7617007179518, -122.42158168137)  15006027571000
# 1  (37.7841907151119, -122.414406029855)  15009821003074
# 2  (37.7841907151119, -122.414406029855)  15009821004014
# 3  (37.7841907151119, -122.414406029855)  15009821015200
# 4  (37.8004687042875, -122.431118543788)  15009822628160

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215024 entries, 0 to 2215023
# Data columns (total 13 columns):
# IncidntNum    int64
# Category      object
# Descript      object
# DayOfWeek     object
# Date          datetime64[ns]
# Time          object
# PdDistrict    object
# Resolution    object
# Address       object
# X             float64
# Y             float64
# Location      object
# PdId          int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(8)
# memory usage: 219.7+ MB

# %%
df["Date"].max()
# Out:
# Timestamp('2018-05-15 00:00:00')

# %%
start_date = df["Date"].max() - dt.timedelta(weeks=11*52)

# %%
cleaned = df[df["Date"] >= start_date]

# %%
cleaned["Year"] = cleaned["Date"].dt.year

# %%
cleaned = cleaned.drop(columns=["Descript", "Date", "Resolution"])

# %%
cleaned.head()
# Out:
#           Category  PdDistrict  Year
# 0     NON-CRIMINAL     MISSION  2015
# 1          ROBBERY  TENDERLOIN  2015
# 2          ASSAULT  TENDERLOIN  2015
# 3  SECONDARY CODES  TENDERLOIN  2015
# 4        VANDALISM    NORTHERN  2015

# %%
cleaned = cleaned.rename(columns={"Category": "Incidents", "PdDistrict": "Neighborhood"})
cleaned.head()
# Out:
#          Incidents Neighborhood  Year
# 0     NON-CRIMINAL      MISSION  2015
# 1          ROBBERY   TENDERLOIN  2015
# 2          ASSAULT   TENDERLOIN  2015
# 3  SECONDARY CODES   TENDERLOIN  2015
# 4        VANDALISM     NORTHERN  2015

# %%
# cleaned.loc["BAYVIEW", "NORTHERN", "MISSION"]]

bayview = cleaned.loc[cleaned['Neighborhood'] == 'BAYVIEW']
mission = cleaned.loc[cleaned['Neighborhood'] == 'MISSION']
northern = cleaned.loc[cleaned['Neighborhood'] == 'NORTHERN']

# %%
merge = bayview.merge(mission, how = 'outer')
final = merge.merge(northern, how = 'outer')
final
# Out:
#                           Incidents Neighborhood  Year
# 0                   SECONDARY CODES      BAYVIEW  2015
# 1                   SECONDARY CODES      BAYVIEW  2015
# 2                   SECONDARY CODES      BAYVIEW  2015
# 3                   SECONDARY CODES      BAYVIEW  2015
# 4                   SECONDARY CODES      BAYVIEW  2015
# 5                   SECONDARY CODES      BAYVIEW  2015
# 6                   SECONDARY CODES      BAYVIEW  2015
# 7                   SECONDARY CODES      BAYVIEW  2015
# 8                   SECONDARY CODES      BAYVIEW  2015
# 9                   SECONDARY CODES      BAYVIEW  2015
# 10                  SECONDARY CODES      BAYVIEW  2015
# 11                  SECONDARY CODES      BAYVIEW  2015
# 12                  SECONDARY CODES      BAYVIEW  2015
# 13                  SECONDARY CODES      BAYVIEW  2015
# 14                  SECONDARY CODES      BAYVIEW  2015
# 15                  SECONDARY CODES      BAYVIEW  2015
# 16                  SECONDARY CODES      BAYVIEW  2015
# 17                  SECONDARY CODES      BAYVIEW  2015
# 18                  SECONDARY CODES      BAYVIEW  2015
# 19                  SECONDARY CODES      BAYVIEW  2015
# 20                  SECONDARY CODES      BAYVIEW  2015
# 21                  SECONDARY CODES      BAYVIEW  2015
# 22                  SECONDARY CODES      BAYVIEW  2015
# 23                  SECONDARY CODES      BAYVIEW  2015
# 24                  SECONDARY CODES      BAYVIEW  2015
# 25                  SECONDARY CODES      BAYVIEW  2015
# 26                  SECONDARY CODES      BAYVIEW  2015
# 27                  SECONDARY CODES      BAYVIEW  2015
# 28                  SECONDARY CODES      BAYVIEW  2015
# 29                  SECONDARY CODES      BAYVIEW  2015
# ...                             ...          ...   ...
# 556803  DRIVING UNDER THE INFLUENCE     NORTHERN  2017
# 556804  DRIVING UNDER THE INFLUENCE     NORTHERN  2017
# 556805  DRIVING UNDER THE INFLUENCE     NORTHERN  2017
# 556806              FAMILY OFFENSES     NORTHERN  2016
# 556807              FAMILY OFFENSES     NORTHERN  2016
# 556808              FAMILY OFFENSES     NORTHERN  2016
# 556809              FAMILY OFFENSES     NORTHERN  2016
# 556810              FAMILY OFFENSES     NORTHERN  2016
# 556811                   BAD CHECKS     NORTHERN  2016
# 556812                   BAD CHECKS     NORTHERN  2016
# 556813                   BAD CHECKS     NORTHERN  2016
# 556814                   BAD CHECKS     NORTHERN  2016
# 556815   SEX OFFENSES, NON FORCIBLE     NORTHERN  2016
# 556816   SEX OFFENSES, NON FORCIBLE     NORTHERN  2016
# 556817   SEX OFFENSES, NON FORCIBLE     NORTHERN  2016
# 556818                    EXTORTION     NORTHERN  2016
# 556819   SEX OFFENSES, NON FORCIBLE     NORTHERN  2017
# 556820   SEX OFFENSES, NON FORCIBLE     NORTHERN  2017
# 556821   SEX OFFENSES, NON FORCIBLE     NORTHERN  2017
# 556822                      BRIBERY     NORTHERN  2017
# 556823                      BRIBERY     NORTHERN  2017
# 556824                      BRIBERY     NORTHERN  2017
# 556825                      BRIBERY     NORTHERN  2017
# 556826                      BRIBERY     NORTHERN  2017
# 556827                      BRIBERY     NORTHERN  2017
# 556828                      BRIBERY     NORTHERN  2017
# 556829                      BRIBERY     NORTHERN  2017
# 556830                     GAMBLING     NORTHERN  2017
# 556831                    LOITERING     NORTHERN  2017
# 556832                    LOITERING     NORTHERN  2017
#
# [556833 rows x 3 columns]

# %%
tbp = final.groupby(['Neighborhood', 'Year']).count()
tbp = tbp.reset_index()

# %%
omega = tbp.pivot(index = 'Year', columns = 'Neighborhood', values = 'Incidents')

# %%
omega.plot()
